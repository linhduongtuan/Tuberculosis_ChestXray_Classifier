# %%
import os
import re
import PIL
import sys
import json
import time
import timm
import math
import copy
import torch
import pickle
import logging
import fnmatch
import argparse
import itertools
import torchvision
import numpy as np
# %matplotlib inline
import pandas as pd
import seaborn as sns
import albumentations
import torch.nn as nn
from PIL import Image
from pathlib import Path
from copy import deepcopy
from sklearn import metrics
import torch.optim as optim
from datetime import datetime
from torchvision import models
import matplotlib.pyplot as plt
import torch.nn.functional as F
import torch.utils.data as data
from torch.autograd import Variable
from tqdm import tqdm, tqdm_notebook
from torch.optim import lr_scheduler
#from pytorch_metric_learning import loss
import torch.utils.model_zoo as model_zoo
from timm.models.layers.activations import *
from timm.utils import accuracy, AverageMeter
# %config InlineBackend.figure_format = 'retina'
from collections import OrderedDict, defaultdict
from torch.utils.tensorboard import SummaryWriter
from torchvision import transforms, models, datasets
from torch.utils.data.sampler import SubsetRandomSampler
from randaugment import RandAugment, ImageNetPolicy, Cutout
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
from timm.loss import LabelSmoothingCrossEntropy, SoftTargetCrossEntropy
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score, roc_curve, auc, roc_auc_score
#from timm.data import Dataset, DatasetTar, RealLabelsImagenet, create_loader, Mixup, FastCollateMixup, AugMixDataset

# %%
torch.backends.cudnn.benchmark = True
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True

# %%
data_dir = '/home/linh/Downloads/TB/'


# Define your transforms for the training and testing sets
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomRotation(30),
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        RandAugment(),
        ImageNetPolicy(),
        Cutout(size=16),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], 
                             [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], 
                             [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], 
                             [0.229, 0.224, 0.225])
    ])
}
"""

image_size=224

data_transforms = {
    'train': albumentations.Compose([
                                    albumentations.Transpose(p=0.5),
                                    albumentations.VerticalFlip(p=0.5),
                                    albumentations.HorizontalFlip(p=0.5),
                                    albumentations.RandomBrightness(limit=0.2, p=0.75),
                                    albumentations.RandomContrast(limit=0.2, p=0.75),
                                    albumentations.OneOf([
                                    albumentations.MotionBlur(blur_limit=5),
                                    albumentations.MedianBlur(blur_limit=5),
                                    albumentations.GaussianBlur(blur_limit=5),
                                    albumentations.GaussNoise(var_limit=(5.0, 30.0)),
                                                            ], p=0.7),

                                    albumentations.OneOf([
                                    albumentations.OpticalDistortion(distort_limit=1.0),
                                    albumentations.GridDistortion(num_steps=5, distort_limit=1.),
                                    albumentations.ElasticTransform(alpha=3),
                                                         ], p=0.7),

                                    albumentations.CLAHE(clip_limit=4.0, p=0.7),
                                    albumentations.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=20, val_shift_limit=10, p=0.5),
                                    albumentations.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=15, border_mode=0, p=0.85),
                                    albumentations.Resize(image_size, image_size),
                                    albumentations.Cutout(max_h_size=int(image_size * 0.375), max_w_size=int(image_size * 0.375), num_holes=1, p=0.7),
                                    albumentations.Normalize(),
                                    RandAugment(),
                                    ImageNetPolicy(),
                                    Cutout(size=16)
                                    ]),

    'val': albumentations.Compose([albumentations.Resize(image_size, image_size),
                                   albumentations.Normalize(),
                                   albumentations.CenterCrop(256)
                                  ])
                    }
"""
# Load the datasets with ImageFolder
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val', 'test']}
batch_size = 70
data_loader = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size,
                                             shuffle=True, num_workers=8, pin_memory = True)
              for x in ['train', 'val', 'test']}

dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}

class_names = image_datasets['train'].classes
print(class_names)
print(dataset_sizes)
print(device)

### we get the class_to_index in the data_Set but what we really need is the cat_to_names  so we will create
_ = image_datasets['train'].class_to_idx
cat_to_name = {_[i]: i for i in list(_.keys())}
print(cat_to_name)
    
# Run this to test the data loader
images, labels = next(iter(data_loader['val']))
images.size()
# Out:
# ['Normal', 'TB']
# {'train': 1319, 'val': 165}
# cuda:0
# {0: 'Normal', 1: 'TB'}
# torch.Size([70, 3, 224, 224])

# %%
def showimage(data_loader, number_images, cat_to_name):
    dataiter = iter(data_loader)
    images, labels = dataiter.next()
    images = images.numpy() # convert images to numpy for display
    # plot the images in the batch, along with the corresponding labels
    fig = plt.figure(figsize=(number_images, 4))
    for idx in np.arange(number_images):
        ax = fig.add_subplot(4, number_images/2, idx+1, xticks=[], yticks=[])
        img = np.transpose(images[idx])
        plt.imshow(img)
        ax.set_title(cat_to_name[labels.tolist()[idx]])
        
#### to show some  images
showimage(data_loader['test'], 10, cat_to_name)
# Out:
# /home/linh/anaconda3/envs/fa/lib/python3.7/site-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#model = models.resnet50(pretrained=True)
#model = timm.create_model('resnet50', pretrained=True)
model = timm.create_model('efficientnet_b2', pretrained=True, drop_rate=0.3)
#model.fc #show fully connected layer for ResNet family
model.classifier #show the classifier layer (fully connected layer) for EfficientNets
# Out:
# Linear(in_features=1408, out_features=1000, bias=True)

# %%
# Create classifier
for param in model.parameters():
    param.requires_grad = True
# define `classifier` for ResNet
# Otherwise, define `fc` for EfficientNet family 
#because the definition of the full connection/classifier of 2 CNN families is differnt
fc = nn.Sequential(OrderedDict([('fc1', nn.Linear(2048, 1000, bias=True)),
							     ('BN1', nn.BatchNorm2d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
								 ('dropout1', nn.Dropout(0.7)),
                                 ('fc2', nn.Linear(1000, 512)),
								 ('BN2', nn.BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
								 ('swish1', Swish()),
								 ('dropout2', nn.Dropout(0.5)),
								 ('fc3', nn.Linear(512, 128)),
								 ('BN3', nn.BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
							     ('swish2', Swish()),
								 ('fc4', nn.Linear(128, 2)),
								 ('output', nn.Softmax(dim=1))
							 ]))
# connect base model (EfficientNet_B0) with modified classifier layer
model.fc = fc
criterion = LabelSmoothingCrossEntropy()
#criterion = nn.CrossEntropyLoss()
#optimizer = Nadam(model.parameters(), lr=0.001)
#optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=0.0001)
optimizer = optim.SGD(model.parameters(), 
                      lr=0.01,momentum=0.9,
                      nesterov=True,
                      weight_decay=0.0001)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)
#show our model architechture and send to GPU
model.to(device)

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
count = count_parameters(model)
print("The number of parameters of the model is:", count)
# Out:
# The number of parameters of the model is: 11740708

# %%
model.to(device)
def train_model(model, criterion, optimizer, scheduler, num_epochs=200, checkpoint = None):
    since = time.time()

    if checkpoint is None:
        best_model_wts = copy.deepcopy(model.state_dict())
        best_loss = math.inf
        best_acc = 0.
    else:
        print(f'Val loss: {checkpoint["best_val_loss"]}, Val accuracy: {checkpoint["best_val_accuracy"]}')
        model.load_state_dict(checkpoint['model_state_dict'])
        best_model_wts = copy.deepcopy(model.state_dict())
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
        best_loss = checkpoint['best_val_loss']
        best_acc = checkpoint['best_val_accuracy']
   
    # Tensorboard summary
    writer = SummaryWriter()
    start_time_per_epoch = time.time()
    
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch + 1, num_epochs)) #(epoch, num_epochs -1)
        print('-' * 20)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for i, (inputs, labels) in enumerate(data_loader[phase]):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()
                
                if i % 1000 == 999:
                    print('[%d, %d] loss: %.8f' % 
                          (epoch + 1, i, running_loss / (i * inputs.size(0))))

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':                
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            
            if phase == 'train':                
                scheduler.step()
                
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.8f} Acc: {:.8f}'.format(
                phase, epoch_loss, epoch_acc))
            
            # Record training loss and accuracy for each phase
            if phase == 'train':
                writer.add_scalar('Train/Loss', epoch_loss, epoch)
                writer.add_scalar('Train/Accuracy', epoch_acc, epoch)
                writer.flush()
            else:
                writer.add_scalar('Valid/Loss', epoch_loss, epoch)
                writer.add_scalar('Valid/Accuracy', epoch_acc, epoch)
                writer.flush()
            # deep copy the model
            
            if phase == 'val' and epoch_acc > best_acc:
                print(f'New best model found!')
                print(f'New record ACC: {epoch_acc}, previous record acc: {best_acc}')
                best_loss = epoch_loss
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
                torch.save({'model_state_dict': model.state_dict(),
                            'optimizer_state_dict': optimizer.state_dict(),
                            'best_val_loss': best_loss,
                            'best_val_accuracy': best_acc,
                            'scheduler_state_dict' : scheduler.state_dict(),
                            }, 
                            CHECK_POINT_PATH
                            )
                print(f'New record acc is SAVED: {epoch_acc}')
                
        end_time_per_epoch = (time.time() - start_time_per_epoch)
        print('Time for training the last epoch: {:.0f}m {:.0f}s'.format(
        end_time_per_epoch // 60, end_time_per_epoch % 60))
        
    time_elapsed = time.time() - since
    print('Total training time complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:.8f} Best val loss: {:.8f}'.format(best_acc, best_loss))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, best_loss, best_acc

# %%
# %time

CHECK_POINT_PATH = '/home/linh/Downloads/TB/weights/EfficientNet_B2.pth'

try:
    checkpoint = torch.load(CHECK_POINT_PATH)
    print("checkpoint loaded")
except:
    checkpoint = None
    print("checkpoint not found")
if checkpoint == None:
    CHECK_POINT_PATH = CHECK_POINT_PATH
model, best_val_loss, best_val_acc = train_model(model,
                                                 criterion,
                                                 optimizer,
                                                 scheduler,
                                                 num_epochs = 100,
                                                 checkpoint = None #torch.load(CHECK_POINT_PATH)
                                                 ) 
                                                
torch.save({'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'best_val_loss': best_val_loss,
            'best_val_accuracy': best_val_acc,
            'scheduler_state_dict': scheduler.state_dict(),
            }, CHECK_POINT_PATH)
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.72 µs
# checkpoint not found
# Epoch 1/100
# --------------------
# train Loss: 3.60958243 Acc: 0.49962092
# val Loss: 1.72949250 Acc: 0.78181818
# New best model found!
# New record ACC: 0.7818181818181819, previous record acc: 0.0
# New record acc is SAVED: 0.7818181818181819
# Time for training the last epoch: 0m 35s
# Epoch 2/100
# --------------------
# train Loss: 1.59638250 Acc: 0.80667172
# val Loss: 1.41849778 Acc: 0.86666667
# New best model found!
# New record ACC: 0.8666666666666667, previous record acc: 0.7818181818181819
# New record acc is SAVED: 0.8666666666666667
# Time for training the last epoch: 1m 7s
# Epoch 3/100
# --------------------
# train Loss: 1.46142412 Acc: 0.82865807
# val Loss: 1.32160245 Acc: 0.89696970
# New best model found!
# New record ACC: 0.896969696969697, previous record acc: 0.8666666666666667
# New record acc is SAVED: 0.896969696969697
# Time for training the last epoch: 1m 38s
# Epoch 4/100
# --------------------
# train Loss: 1.40349813 Acc: 0.84609553
# val Loss: 1.27803519 Acc: 0.91515152
# New best model found!
# New record ACC: 0.9151515151515152, previous record acc: 0.896969696969697
# New record acc is SAVED: 0.9151515151515152
# Time for training the last epoch: 2m 13s
# Epoch 5/100
# --------------------
# train Loss: 1.41812221 Acc: 0.84078848
# val Loss: 1.32124359 Acc: 0.88484848
# Time for training the last epoch: 2m 45s
# Epoch 6/100
# --------------------
# train Loss: 1.37238887 Acc: 0.84988628
# val Loss: 1.27235435 Acc: 0.91515152
# Time for training the last epoch: 3m 19s
# Epoch 7/100
# --------------------
# train Loss: 1.37375290 Acc: 0.85595148
# val Loss: 1.23601158 Acc: 0.91515152
# Time for training the last epoch: 3m 51s
# Epoch 8/100
# --------------------
# train Loss: 1.36984347 Acc: 0.84836998
# val Loss: 1.23623577 Acc: 0.91515152
# Time for training the last epoch: 4m 22s
# Epoch 9/100
# --------------------
# train Loss: 1.34281912 Acc: 0.86504928
# val Loss: 1.24715384 Acc: 0.92121212
# New best model found!
# New record ACC: 0.9212121212121213, previous record acc: 0.9151515151515152
# New record acc is SAVED: 0.9212121212121213
# Time for training the last epoch: 4m 53s
# Epoch 10/100
# --------------------
# train Loss: 1.33237133 Acc: 0.86732373
# val Loss: 1.24038605 Acc: 0.90909091
# Time for training the last epoch: 5m 24s
# Epoch 11/100
# --------------------
# train Loss: 1.31245227 Acc: 0.88855193
# val Loss: 1.22570449 Acc: 0.91515152
# Time for training the last epoch: 5m 55s
# Epoch 12/100
# --------------------
# train Loss: 1.32819139 Acc: 0.86959818
# val Loss: 1.21462237 Acc: 0.92727273
# New best model found!
# New record ACC: 0.9272727272727272, previous record acc: 0.9212121212121213
# New record acc is SAVED: 0.9272727272727272
# Time for training the last epoch: 6m 27s
# Epoch 13/100
# --------------------
# train Loss: 1.32366225 Acc: 0.87035633
# val Loss: 1.26452056 Acc: 0.90303030
# Time for training the last epoch: 6m 60s
# Epoch 14/100
# --------------------
# train Loss: 1.29792788 Acc: 0.87111448
# val Loss: 1.17992023 Acc: 0.95151515
# New best model found!
# New record ACC: 0.9515151515151515, previous record acc: 0.9272727272727272
# New record acc is SAVED: 0.9515151515151515
# Time for training the last epoch: 7m 36s
# Epoch 15/100
# --------------------
# train Loss: 1.29402894 Acc: 0.89006823
# val Loss: 1.19188056 Acc: 0.93939394
# Time for training the last epoch: 8m 8s
# Epoch 16/100
# --------------------
# train Loss: 1.26558374 Acc: 0.90144049
# val Loss: 1.19735414 Acc: 0.92727273
# Time for training the last epoch: 8m 39s
# Epoch 17/100
# --------------------
# train Loss: 1.29405454 Acc: 0.87945413
# val Loss: 1.19561400 Acc: 0.92727273
# Time for training the last epoch: 9m 11s
# Epoch 18/100
# --------------------
# train Loss: 1.28957063 Acc: 0.88400303
# val Loss: 1.20467296 Acc: 0.90909091
# Time for training the last epoch: 9m 43s
# Epoch 19/100
# --------------------
# train Loss: 1.27279344 Acc: 0.89537528
# val Loss: 1.17322373 Acc: 0.93939394
# Time for training the last epoch: 10m 14s
# Epoch 20/100
# --------------------
# train Loss: 1.28293831 Acc: 0.88400303
# val Loss: 1.17611558 Acc: 0.93939394
# Time for training the last epoch: 10m 46s
# Epoch 21/100
# --------------------
# train Loss: 1.27763265 Acc: 0.89537528
# val Loss: 1.16023238 Acc: 0.94545455
# Time for training the last epoch: 11m 16s
# Epoch 22/100
# --------------------
# train Loss: 1.28864013 Acc: 0.87642153
# val Loss: 1.16161806 Acc: 0.95757576
# New best model found!
# New record ACC: 0.9575757575757575, previous record acc: 0.9515151515151515
# New record acc is SAVED: 0.9575757575757575
# Time for training the last epoch: 11m 48s
# Epoch 23/100
# --------------------
# train Loss: 1.26542988 Acc: 0.89916603
# val Loss: 1.17147481 Acc: 0.93333333
# Time for training the last epoch: 12m 22s
# Epoch 24/100
# --------------------
# train Loss: 1.24600019 Acc: 0.91053829
# val Loss: 1.15991363 Acc: 0.93939394
# Time for training the last epoch: 12m 55s
# Epoch 25/100
# --------------------
# train Loss: 1.27473407 Acc: 0.89006823
# val Loss: 1.18519885 Acc: 0.95151515
# Time for training the last epoch: 13m 24s
# Epoch 26/100
# --------------------
# train Loss: 1.25742570 Acc: 0.90826384
# val Loss: 1.16171864 Acc: 0.93939394
# Time for training the last epoch: 13m 55s
# Epoch 27/100
# --------------------
# train Loss: 1.25193466 Acc: 0.89613343
# val Loss: 1.16541053 Acc: 0.94545455
# Time for training the last epoch: 14m 26s
# Epoch 28/100
# --------------------
# train Loss: 1.25155608 Acc: 0.90144049
# val Loss: 1.15563658 Acc: 0.95151515
# Time for training the last epoch: 14m 59s
# Epoch 29/100
# --------------------
# train Loss: 1.24227400 Acc: 0.90598939
# val Loss: 1.16274871 Acc: 0.93333333
# Time for training the last epoch: 15m 31s
# Epoch 30/100
# --------------------
# train Loss: 1.22806647 Acc: 0.91963609
# val Loss: 1.15950755 Acc: 0.94545455
# Time for training the last epoch: 15m 59s
# Epoch 31/100
# --------------------
# train Loss: 1.24841155 Acc: 0.90598939
# val Loss: 1.15106554 Acc: 0.94545455
# Time for training the last epoch: 16m 30s
# Epoch 32/100
# --------------------
# train Loss: 1.23860275 Acc: 0.90523124
# val Loss: 1.14885721 Acc: 0.94545455
# Time for training the last epoch: 16m 60s
# Epoch 33/100
# --------------------
# train Loss: 1.22878186 Acc: 0.91281274
# val Loss: 1.14594685 Acc: 0.95151515
# Time for training the last epoch: 17m 32s
# Epoch 34/100
# --------------------
# train Loss: 1.23665102 Acc: 0.90750569
# val Loss: 1.14412183 Acc: 0.95151515
# Time for training the last epoch: 18m 2s
# Epoch 35/100
# --------------------
# train Loss: 1.23245264 Acc: 0.91357089
# val Loss: 1.14442523 Acc: 0.95151515
# Time for training the last epoch: 18m 36s
# Epoch 36/100
# --------------------
# train Loss: 1.23052508 Acc: 0.90978014
# val Loss: 1.14379851 Acc: 0.95151515
# Time for training the last epoch: 19m 7s
# Epoch 37/100
# --------------------
# train Loss: 1.23432990 Acc: 0.89840788
# val Loss: 1.14435576 Acc: 0.95151515
# Time for training the last epoch: 19m 39s
# Epoch 38/100
# --------------------
# train Loss: 1.22518303 Acc: 0.91205459
# val Loss: 1.14259527 Acc: 0.95151515
# Time for training the last epoch: 20m 10s
# Epoch 39/100
# --------------------
# train Loss: 1.25494421 Acc: 0.89613343
# val Loss: 1.14373168 Acc: 0.95151515
# Time for training the last epoch: 20m 40s
# Epoch 40/100
# --------------------
# train Loss: 1.22876181 Acc: 0.90902199
# val Loss: 1.14286669 Acc: 0.95151515
# Time for training the last epoch: 21m 13s
# Epoch 41/100
# --------------------
# train Loss: 1.22943302 Acc: 0.91205459
# val Loss: 1.14303998 Acc: 0.94545455
# Time for training the last epoch: 21m 45s
# Epoch 42/100
# --------------------
# train Loss: 1.23100004 Acc: 0.90219864
# val Loss: 1.14478547 Acc: 0.94545455
# Time for training the last epoch: 22m 17s
# Epoch 43/100
# --------------------
# train Loss: 1.21463432 Acc: 0.91963609
# val Loss: 1.14433324 Acc: 0.95151515
# Time for training the last epoch: 22m 47s
# Epoch 44/100
# --------------------
# train Loss: 1.22234877 Acc: 0.91736164
# val Loss: 1.14346315 Acc: 0.95151515
# Time for training the last epoch: 23m 18s
# Epoch 45/100
# --------------------
# train Loss: 1.22916446 Acc: 0.90902199
# val Loss: 1.14277711 Acc: 0.95151515
# Time for training the last epoch: 23m 49s
# Epoch 46/100
# --------------------
# train Loss: 1.22699992 Acc: 0.90750569
# val Loss: 1.14157646 Acc: 0.95757576
# Time for training the last epoch: 24m 21s
# Epoch 47/100
# --------------------
# train Loss: 1.21960876 Acc: 0.92191054
# val Loss: 1.14245112 Acc: 0.95757576
# Time for training the last epoch: 24m 53s
# Epoch 48/100
# --------------------
# train Loss: 1.23234181 Acc: 0.90978014
# val Loss: 1.14172709 Acc: 0.94545455
# Time for training the last epoch: 25m 25s
# Epoch 49/100
# --------------------
# train Loss: 1.21402629 Acc: 0.92266869
# val Loss: 1.14187358 Acc: 0.94545455
# Time for training the last epoch: 25m 54s
# Epoch 50/100
# --------------------
# train Loss: 1.22749413 Acc: 0.91660349
# val Loss: 1.14100489 Acc: 0.95151515
# Time for training the last epoch: 26m 26s
# Epoch 51/100
# --------------------
# train Loss: 1.22929941 Acc: 0.90750569
# val Loss: 1.14154373 Acc: 0.95151515
# Time for training the last epoch: 26m 56s
# Epoch 52/100
# --------------------
# train Loss: 1.23032582 Acc: 0.90826384
# val Loss: 1.14054671 Acc: 0.95151515
# Time for training the last epoch: 27m 29s
# Epoch 53/100
# --------------------
# train Loss: 1.22936841 Acc: 0.90598939
# val Loss: 1.14140383 Acc: 0.95151515
# Time for training the last epoch: 28m 0s
# Epoch 54/100
# --------------------
# train Loss: 1.21006585 Acc: 0.91660349
# val Loss: 1.14122394 Acc: 0.95151515
# Time for training the last epoch: 28m 31s
# Epoch 55/100
# --------------------
# train Loss: 1.24195399 Acc: 0.90144049
# val Loss: 1.13926689 Acc: 0.94545455
# Time for training the last epoch: 29m 3s
# Epoch 56/100
# --------------------
# train Loss: 1.21382365 Acc: 0.91053829
# val Loss: 1.13856017 Acc: 0.95757576
# Time for training the last epoch: 29m 33s
# Epoch 57/100
# --------------------
# train Loss: 1.23196459 Acc: 0.91129644
# val Loss: 1.14133603 Acc: 0.95757576
# Time for training the last epoch: 30m 4s
# Epoch 58/100
# --------------------
# train Loss: 1.22577436 Acc: 0.91129644
# val Loss: 1.14308455 Acc: 0.95757576
# Time for training the last epoch: 30m 35s
# Epoch 59/100
# --------------------
# train Loss: 1.20367485 Acc: 0.92721759
# val Loss: 1.14486337 Acc: 0.95151515
# Time for training the last epoch: 31m 7s
# Epoch 60/100
# --------------------
# train Loss: 1.21465218 Acc: 0.91357089
# val Loss: 1.14422643 Acc: 0.95757576
# Time for training the last epoch: 31m 38s
# Epoch 61/100
# --------------------
# train Loss: 1.21975138 Acc: 0.92494314
# val Loss: 1.14015553 Acc: 0.95151515
# Time for training the last epoch: 32m 8s
# Epoch 62/100
# --------------------
# train Loss: 1.23820086 Acc: 0.90295679
# val Loss: 1.14169182 Acc: 0.95757576
# Time for training the last epoch: 32m 40s
# Epoch 63/100
# --------------------
# train Loss: 1.22094247 Acc: 0.91205459
# val Loss: 1.14051365 Acc: 0.95151515
# Time for training the last epoch: 33m 12s
# Epoch 64/100
# --------------------
# train Loss: 1.21651598 Acc: 0.91432904
# val Loss: 1.14336033 Acc: 0.95757576
# Time for training the last epoch: 33m 43s
# Epoch 65/100
# --------------------
# train Loss: 1.20786334 Acc: 0.92266869
# val Loss: 1.14105193 Acc: 0.95757576
# Time for training the last epoch: 34m 12s
# Epoch 66/100
# --------------------
# train Loss: 1.21422227 Acc: 0.92191054
# val Loss: 1.14099998 Acc: 0.95757576
# Time for training the last epoch: 34m 47s
# Epoch 67/100
# --------------------
# train Loss: 1.22525316 Acc: 0.89992418
# val Loss: 1.14076805 Acc: 0.95757576
# Time for training the last epoch: 35m 18s
# Epoch 68/100
# --------------------
# train Loss: 1.21346939 Acc: 0.92191054
# val Loss: 1.14095832 Acc: 0.95757576
# Time for training the last epoch: 35m 49s
# Epoch 69/100
# --------------------
# train Loss: 1.21072144 Acc: 0.92494314
# val Loss: 1.14048057 Acc: 0.95757576
# Time for training the last epoch: 36m 18s
# Epoch 70/100
# --------------------
# train Loss: 1.21344421 Acc: 0.92570129
# val Loss: 1.14055146 Acc: 0.95757576
# Time for training the last epoch: 36m 52s
# Epoch 71/100
# --------------------
# train Loss: 1.21839538 Acc: 0.91887794
# val Loss: 1.14201125 Acc: 0.95757576
# Time for training the last epoch: 37m 22s
# Epoch 72/100
# --------------------
# train Loss: 1.21613623 Acc: 0.91963609
# val Loss: 1.14133722 Acc: 0.95757576
# Time for training the last epoch: 37m 52s
# Epoch 73/100
# --------------------
# train Loss: 1.20530275 Acc: 0.91811979
# val Loss: 1.14137527 Acc: 0.95757576
# Time for training the last epoch: 38m 22s
# Epoch 74/100
# --------------------
# train Loss: 1.20928274 Acc: 0.92115239
# val Loss: 1.14159438 Acc: 0.95757576
# Time for training the last epoch: 38m 52s
# Epoch 75/100
# --------------------
# train Loss: 1.22154855 Acc: 0.91432904
# val Loss: 1.14124474 Acc: 0.95757576
# Time for training the last epoch: 39m 24s
# Epoch 76/100
# --------------------
# train Loss: 1.21877533 Acc: 0.91508719
# val Loss: 1.14064107 Acc: 0.95757576
# Time for training the last epoch: 39m 56s
# Epoch 77/100
# --------------------
# train Loss: 1.22410315 Acc: 0.92039424
# val Loss: 1.14077434 Acc: 0.95757576
# Time for training the last epoch: 40m 28s
# Epoch 78/100
# --------------------
# train Loss: 1.22648480 Acc: 0.91205459
# val Loss: 1.14119944 Acc: 0.95757576
# Time for training the last epoch: 41m 0s
# Epoch 79/100
# --------------------
# train Loss: 1.22719497 Acc: 0.91432904
# val Loss: 1.14145681 Acc: 0.95757576
# Time for training the last epoch: 41m 30s
# Epoch 80/100
# --------------------
# train Loss: 1.20801997 Acc: 0.92266869
# val Loss: 1.14117275 Acc: 0.95757576
# Time for training the last epoch: 42m 6s
# Epoch 81/100
# --------------------
# train Loss: 1.21600996 Acc: 0.91811979
# val Loss: 1.14150958 Acc: 0.95757576
# Time for training the last epoch: 42m 36s
# Epoch 82/100
# --------------------
# train Loss: 1.21900690 Acc: 0.90750569
# val Loss: 1.13967879 Acc: 0.95757576
# Time for training the last epoch: 43m 6s
# Epoch 83/100
# --------------------
# train Loss: 1.20863314 Acc: 0.92191054
# val Loss: 1.14016570 Acc: 0.95757576
# Time for training the last epoch: 43m 36s
# Epoch 84/100
# --------------------
# train Loss: 1.22299197 Acc: 0.91736164
# val Loss: 1.14285170 Acc: 0.95757576
# Time for training the last epoch: 44m 8s
# Epoch 85/100
# --------------------
# train Loss: 1.23200227 Acc: 0.90068234
# val Loss: 1.14165621 Acc: 0.95757576
# Time for training the last epoch: 44m 40s
# Epoch 86/100
# --------------------
# train Loss: 1.21822311 Acc: 0.91963609
# val Loss: 1.13967051 Acc: 0.95757576
# Time for training the last epoch: 45m 10s
# Epoch 87/100
# --------------------
# train Loss: 1.20195698 Acc: 0.92570129
# val Loss: 1.14039612 Acc: 0.95757576
# Time for training the last epoch: 45m 41s
# Epoch 88/100
# --------------------
# train Loss: 1.22283137 Acc: 0.91963609
# val Loss: 1.14208932 Acc: 0.95757576
# Time for training the last epoch: 46m 14s
# Epoch 89/100
# --------------------
# train Loss: 1.20914950 Acc: 0.92266869
# val Loss: 1.14315204 Acc: 0.95757576
# Time for training the last epoch: 46m 45s
# Epoch 90/100
# --------------------
# train Loss: 1.22171181 Acc: 0.91053829
# val Loss: 1.14083862 Acc: 0.95757576
# Time for training the last epoch: 47m 15s
# Epoch 91/100
# --------------------
# train Loss: 1.21782221 Acc: 0.91508719
# val Loss: 1.14061592 Acc: 0.95757576
# Time for training the last epoch: 47m 48s
# Epoch 92/100
# --------------------
# train Loss: 1.22519067 Acc: 0.90902199
# val Loss: 1.14133791 Acc: 0.95757576
# Time for training the last epoch: 48m 23s
# Epoch 93/100
# --------------------
# train Loss: 1.20083928 Acc: 0.92873389
# val Loss: 1.14354436 Acc: 0.95757576
# Time for training the last epoch: 48m 54s
# Epoch 94/100
# --------------------
# train Loss: 1.20982642 Acc: 0.92191054
# val Loss: 1.14284568 Acc: 0.95757576
# Time for training the last epoch: 49m 29s
# Epoch 95/100
# --------------------
# train Loss: 1.23095226 Acc: 0.90447309
# val Loss: 1.14057135 Acc: 0.95757576
# Time for training the last epoch: 50m 1s
# Epoch 96/100
# --------------------
# train Loss: 1.21527837 Acc: 0.91508719
# val Loss: 1.14266976 Acc: 0.95151515
# Time for training the last epoch: 50m 31s
# Epoch 97/100
# --------------------
# train Loss: 1.23097460 Acc: 0.91053829
# val Loss: 1.14127685 Acc: 0.95757576
# Time for training the last epoch: 51m 3s
# Epoch 98/100
# --------------------
# train Loss: 1.22064673 Acc: 0.91508719
# val Loss: 1.13932737 Acc: 0.95757576
# Time for training the last epoch: 51m 36s
# Epoch 99/100
# --------------------
# train Loss: 1.19435367 Acc: 0.92342684
# val Loss: 1.14106661 Acc: 0.95757576
# Time for training the last epoch: 52m 8s
# Epoch 100/100
# --------------------
# train Loss: 1.22986587 Acc: 0.90598939
# val Loss: 1.14013888 Acc: 0.95757576
# Time for training the last epoch: 52m 38s
# Total training time complete in 52m 39s
# Best val Acc: 0.95757576 Best val loss: 1.16161806

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.suam(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
def plot_roc_curve(fpr, tpr):
    plt.plot(fpr, tpr, color='darkorange',
         lw=2, label='ROC curve (area = %0.4f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc="lower right")  
    plt.show()

# %%
# %time
CHECK_POINT_PATH = '/home/linh/Downloads/TB/weights/EfficientNet_B2.pth'

try:
    checkpoint = torch.load(CHECK_POINT_PATH)
    print("checkpoint loaded")
except:
    checkpoint = None
    print("checkpoint not found")

def load_model(path):                                
    model.load_state_dict(checkpoint['model_state_dict'])
    best_model_wts = copy.deepcopy(model.state_dict())
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
    best_loss = checkpoint['best_val_loss']
    best_acc = checkpoint['best_val_accuracy']
load_model(CHECK_POINT_PATH) 
model.to(device)
model.eval()
since = time.time()

y_label = []
y_predict = []
with torch.no_grad():
    for i, data in enumerate(data_loader['test']):
        images, labels = data
        N = images.size(0)
        images = Variable(images).to(device)
        outputs = model(images)
        prediction = outputs.max(1, keepdim=True)[1]
        y_label.extend(labels.cpu().numpy())
        y_predict.extend(np.squeeze(prediction.cpu().numpy().T))
        
time_elapsed = time.time() - since

print('Inference time is {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))

# compute the confusion matrix
confusion_mtx = confusion_matrix(y_label, y_predict)
# plot the confusion matrix
plot_labels = ['NORMAL', 'Tuberculosis']

plot_confusion_matrix(confusion_mtx, plot_labels)
report = classification_report(y_label, y_predict, digits=4)
print(report)
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
# checkpoint loaded
# Inference time is 0m 6s
#               precision    recall  f1-score   support
#
#            0     0.9406    0.9794    0.9596        97
#            1     0.9688    0.9118    0.9394        68
#
#     accuracy                         0.9515       165
#    macro avg     0.9547    0.9456    0.9495       165
# weighted avg     0.9522    0.9515    0.9513       165

# %%
roc_auc = roc_auc_score(y_label, y_predict)
print('ROC curve (area = %0.4f)' % roc_auc)
fpr, tpr, thresholds = roc_curve(y_label, y_predict)
plot_roc_curve(fpr, tpr)
# Out:
# ROC curve (area = 0.9456)

# %%
def get_preds(model,device=None,tta=3):
    device=torch.device("cuda:1")
    model.to(device)
    preds = np.zeros(len(dataset_sizes['test']))
    for tta_id in range(tta):
        test_preds = []
        with torch.no_grad():
            for xb in data_loader['test']:
                xb = xb.to(device)
                out = model(xb)
                out = torch.sigmoid(out)
                test_preds.extend(out.cpu().numpy())
            preds += np.array(test_preds).reshape(-1)
        print(f'TTA {tta_id}')
    preds /= tta
    return preds
preds = get_preds(model,tta=25)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-70cd434106ff> in <module>
#      15     preds /= tta
#      16     return preds
# ---> 17 preds = get_preds(model,tta=25)
#
# <ipython-input-12-70cd434106ff> in get_preds(model, device, tta)
#       2     device=torch.device("cuda:1")
#       3     model.to(device)
# ----> 4     preds = np.zeros(len(dataset_sizes['test']))
#       5     for tta_id in range(tta):
#       6         test_preds = []
#
# KeyError: 'test'

# %%
subm = pd.read_csv("/home/linh/Downloads/TB/SampleSubmission.csv")
subm.LABEL = preds
subm.to_csv('/home/linh/Downloads/TB/submission.csv',index=False)
